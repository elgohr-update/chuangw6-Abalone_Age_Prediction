# %% [markdown]
# # Exploratory data analysis of the Abalone data set

# %% [markdown]
# ## Summary of the data set
#
# The dataset used in this project comes from an original study "The Population Biology of Abalone (_Haliotis_ species) in Tasmania. I. Blacklip Abalone (_H. rubra_) from the North Coast and Islands of Bass Strait", created by Warwick J Nash, Tracy L Sellers, Simon R Talbot, Andrew J Cawthorn and Wes B Ford (1994). It was sourced from the UCI Machine Learning Repository and can be found [here](http://archive.ics.uci.edu/ml/machine-learning-databases/abalone/). Each row in the data set represents an abalone, including the physical measurements(Sex, Length, Diameter, Height, Whole weight, etc.) and the number of rings, which gives the age in years by adding 1.5. The missing values in the original study have been removed and the range of continuous values has been scaled. Please find the detailed information [here](http://archive.ics.uci.edu/ml/datasets/Abalone?pagewanted=all).

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
import altair as alt
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Raw Data and Preprocessing

# %%
abalone = pd.read_csv("../data/raw/abalone.csv")
abalone.columns = ['Sex', 'Length', 'Diameter', 'Height',
                   'Whole Weight', 'Shucked Weight',
                   'Viscera Weight', 'Shell Weight', 'Rings']

abalone['Age'] = abalone['Rings'] + 1.5
abalone = abalone.drop(columns = 'Rings')
train_df, test_df = train_test_split(abalone, test_size = 0.2, random_state=123)

# %% [markdown]
# ## Exploratory analysis on the training data set

# %% [markdown]
# ### Missing Values

# %%
train_df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole Weight      0
# Shucked Weight    0
# Viscera Weight    0
# Shell Weight      0
# Age               0
# dtype: int64

# %% [markdown]
# There aren't any missing values in the training data.

# %% [markdown]
# ### Attribute Information

# %%
train_df.head()
# Out:
#      Sex  Length  Diameter  Height  Whole Weight  Shucked Weight  \
# 2746   I   0.490     0.365   0.125        0.5585          0.2520
# 853    M   0.570     0.435   0.130        0.7535          0.3490
# 1809   M   0.645     0.500   0.160        1.3815          0.6720
# 3419   F   0.595     0.475   0.165        1.1480          0.4440
# 1199   F   0.720     0.550   0.200        1.9965          0.9035
#
#       Viscera Weight  Shell Weight   Age
# 2746          0.1260        0.1615  11.5
# 853           0.1755        0.1940  11.5
# 1809          0.3260        0.3150  10.5
# 3419          0.2140        0.3700  11.5
# 1199          0.4690        0.5215  11.5

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3340 entries, 2746 to 3582
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             3340 non-null   object
#  1   Length          3340 non-null   float64
#  2   Diameter        3340 non-null   float64
#  3   Height          3340 non-null   float64
#  4   Whole Weight    3340 non-null   float64
#  5   Shucked Weight  3340 non-null   float64
#  6   Viscera Weight  3340 non-null   float64
#  7   Shell Weight    3340 non-null   float64
#  8   Age             3340 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 260.9+ KB

# %% [markdown]
# Except `Sex`, all attributes including the target column `Age` are numeric.

# %% [markdown]
# #### Description of each of the attributes:
#
# - **Sex**: M, F, and I (infant)
# - **Length**: Longest shell measurement in mm
# - **Diameter**: perpendicular to length in mm
# - **Height**: with meat in shell in mm
# - **Whole Weight**: whole abalone in grams
# - **Shucked Weight**: weight of meat in grams
# - **Viscera Weight**: gut weight (after bleeding) in grams
# - **Shell Weight**: grams after being dried in grams
# - **Age**: age in years

# %%
train_df.describe()
# Out:
#             Length     Diameter       Height  Whole Weight  Shucked Weight  \
# count  3340.000000  3340.000000  3340.000000   3340.000000     3340.000000
# mean      0.524368     0.408308     0.139644      0.831512        0.360678
# std       0.120470     0.099507     0.042316      0.492492        0.222257
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.440500        0.185000
# 50%       0.545000     0.425000     0.140000      0.801750        0.336000
# 75%       0.615000     0.480000     0.165000      1.165125        0.505500
# max       0.815000     0.650000     1.130000      2.555000        1.253000
#
#        Viscera Weight  Shell Weight          Age
# count     3340.000000   3340.000000  3340.000000
# mean         0.181134      0.239582    11.445808
# std          0.110089      0.139768     3.240171
# min          0.000500      0.001500     2.500000
# ...

# %% [markdown]
# ### Target Column: 'Age'

# %% [markdown]
# #### Distribution of Target Column: 'Age'

# %%
train_df1 = train_df.copy()
train_df1.columns = ['Sex', 'Length (mm)', 'Diameter (mm)', 'Height (mm)', 'Whole Weight (g)', 'Shucked Weight (g)', 'Viscera Weight (g)', 'Shell Weight (g)','Age (Years)']
sns.set(rc={'figure.figsize':(10, 7.5)}, font_scale = 1.25)
sns.set_theme(style="whitegrid")
sns.histplot(train_df1, x = "Age (Years)", kde=True, bins = 15)
# Out:
# <AxesSubplot:xlabel='Age (Years)', ylabel='Count'>

# %% [markdown]
# The distribution of `Age` is approximately normal with a mean of around 11.5 years. However, it does have a slight positive skew

# %% [markdown]
# #### Distribution of 'Age' conditioned on 'Sex':

# %%
sns.set(rc={'figure.figsize':(10, 7.5)}, font_scale = 1.25)
sns.violinplot(y = "Sex", x = "Age (Years)", data = train_df1, inner = "quartile")
# Out:
# <AxesSubplot:xlabel='Age (Years)', ylabel='Sex'>

# %%
df_i = train_df1.loc[train_df1["Sex"] == 'I']
df_m = train_df1.loc[train_df1["Sex"] == 'M']
df_f = train_df1.loc[train_df1["Sex"] == 'F']
summary = pd.concat([train_df.describe()['Age'], df_i[["Age (Years)"]].describe(), df_m[["Age (Years)"]].describe(), df_f[["Age (Years)"]].describe()], axis = 1)
summary.columns = ["Age", "Age - Infant","Age - Male", "Age - Female"]
summary
# Out:
#                Age  Age - Infant   Age - Male  Age - Female
# count  3340.000000   1060.000000  1218.000000   1062.000000
# mean     11.445808      9.349057    12.206076     12.666667
# std       3.240171      2.488851     3.025063      3.132557
# min       2.500000      2.500000     4.500000      6.500000
# 25%       9.500000      7.500000    10.500000     10.500000
# 50%      11.500000      9.500000    11.500000     11.500000
# 75%      12.500000     10.500000    13.500000     13.500000
# max      30.500000     21.500000    28.500000     30.500000

# %% [markdown]
# - The number of instances of Infants, Males and Females are pretty close to each other
# - The mean, median, Q1, and Q3 of `Age` for Infants are all lower than that for Males and Females
# - The mean, median, Q1, Q3 and standard deviation of `Age` are all very close for Males and Females

# %% [markdown]
# #### Scatter Plot of 'Age' with all Numerical Columns

# %%
sns.set(rc={'figure.figsize':(30,12)}, font_scale = 1.25)
fig, axs = plt.subplots(nrows = 2, ncols = 4)
sns.set_theme(style="whitegrid")
sns.histplot(x = "Age (Years)", y = "Length (mm)", data = train_df1, ax = axs[0, 0], binwidth=(1, 0.025))
sns.histplot(x = "Age (Years)", y = "Diameter (mm)", data = train_df1, ax = axs[0, 1], binwidth=(1, 0.025))
sns.histplot(x = "Age (Years)", y = "Height (mm)", data = train_df1, ax = axs[0, 2], binwidth=(1, 0.025))
sns.histplot(x = "Age (Years)", y = "Whole Weight (g)", data = train_df1, ax = axs[0, 3], binwidth=(1, 0.05))
sns.histplot(x = "Age (Years)", y = "Shucked Weight (g)", data = train_df1, ax = axs[1, 0], binwidth=(1, 0.025))
sns.histplot(x = "Age (Years)", y = "Viscera Weight (g)", data = train_df1, ax = axs[1, 1], binwidth=(1, 0.025))
sns.histplot(x = "Age (Years)", y = "Shell Weight (g)", data = train_df1, ax = axs[1, 2], binwidth=(1, 0.02))
fig.delaxes(axs[1,3])

# %% [markdown]
# `Age` seems to be positively correlated with all the numerical features

# %% [markdown]
# ### Histogram of Numerical Columns:

# %%
sns.set(rc={'figure.figsize':(30,12)}, font_scale = 1.25)
fig, axs = plt.subplots(nrows = 2, ncols = 4)
sns.set_theme(style="whitegrid")
sns.histplot(train_df1, x = "Length (mm)", kde = True, bins = 15, ax = axs[0, 0])
sns.histplot(train_df1, x = "Diameter (mm)", kde = True, bins = 15, ax = axs[0, 1])
sns.histplot(train_df1, x = "Height (mm)", kde = True, bins = 20, ax = axs[0, 2])
sns.histplot(train_df1, x = "Whole Weight (g)", kde = True, bins = 15, ax = axs[0, 3])
sns.histplot(train_df1, x = "Shucked Weight (g)", kde = True, bins = 15, ax = axs[1, 0])
sns.histplot(train_df1, x = "Viscera Weight (g)", kde = True, bins = 15, ax = axs[1, 1])
sns.histplot(train_df1, x = "Shell Weight (g)", kde = True, bins = 15, ax = axs[1, 2])
fig.delaxes(axs[1,3])

# %% [markdown]
# The range of numerical features is close. The feature "Whole Weight" distributes from 0 to 2.5, which is a wider range than other features. Other features distribute from 0 to around 1. According to the dataset information on the UCI Machine Learning Repository website, the ranges have been scaled by dividing by 200. Thus, we are going to use the numerical values as our model input, not change the scale.

# %% [markdown]
# ### Pairplot of Numerical Columns:

# %%
sns.pairplot(train_df1, vars = list(train_df1.columns)[1:-1], kind = "hist", diag_kind = "kde", corner = True)

# %% [markdown]
# From the pairplot above, we see that all numerical features have a positive relationship between each other. We are going to use all features as our model input.

# %% [markdown]
# ### Correlation Plot:

# %%
sns.set(rc={'figure.figsize':(15, 10)})
num_data = train_df[list(train_df.columns)[1:]]
ax = sns.heatmap(num_data.corr(),
                 annot = True,
                 annot_kws = {'fontsize': 15},
                 vmin = -1,
                 vmax = 1,
                 cmap = 'Spectral',
                 linewidths=.5)
ax
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Numerical Columns conditioned on 'Sex':

# %%
sns.set(rc={'figure.figsize':(30,12)}, font_scale = 1.25)
fig, axs = plt.subplots(nrows = 2, ncols = 4)
sns.set_theme(style="whitegrid")
sns.violinplot(y = "Sex", x = "Length (mm)", data = train_df1, inner = "quartile", ax = axs[0, 0])
sns.violinplot(y = "Sex", x = "Diameter (mm)", data = train_df1, inner = "quartile", ax = axs[0, 1])
sns.violinplot(y = "Sex", x = "Height (mm)", data = train_df1, inner = "quartile", ax = axs[0, 2])
sns.violinplot(y = "Sex", x = "Whole Weight (g)", data = train_df1, inner = "quartile", ax = axs[0, 3])
sns.violinplot(y = "Sex", x = "Shucked Weight (g)", data = train_df1, inner = "quartile", ax = axs[1, 0])
sns.violinplot(y = "Sex", x = "Viscera Weight (g)", data = train_df1, inner = "quartile", ax = axs[1, 1])
sns.violinplot(y = "Sex", x = "Shell Weight (g)", data = train_df1, inner = "quartile", ax = axs[1, 2])
fig.delaxes(axs[1,3])
